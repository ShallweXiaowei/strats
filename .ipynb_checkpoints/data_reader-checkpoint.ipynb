# %%
import pandas_datareader as pdr
import pandas_datareader.data as web
from datetime import datetime
import os

# %%
os.environ['ALPHAVANTAGE_API_KEY'] = '8061RWJT6KZZKZMP'

# %%
f = web.DataReader("AAPL", "av-intraday", start=datetime(2020, 4, 1),api_key=os.getenv('ALPHAVANTAGE_API_KEY'))

# %%
web.get_sector_performance_av()
# Out:
#                            RT      1D      5D       1M       3M      YTD  \
# Energy                  4.21%   2.00%  10.07%  -22.83%  -46.81%  -46.13%
# Real Estate             3.90%   0.12%   1.35%  -18.14%  -18.39%  -18.75%
# Financials              3.47%   0.94%   2.18%  -16.36%  -30.71%  -30.86%
# Industrials             3.26%  -0.19%   1.81%  -16.48%  -27.31%  -26.10%
# Materials               2.88%   2.42%   4.23%  -11.89%  -20.90%  -23.49%
# Consumer Discretionary  2.79%   1.23%   3.56%   -9.58%  -17.38%  -16.73%
# Utilities               2.66%  -1.21%  -0.57%  -17.30%  -13.79%  -14.68%
# Information Technology  2.62%  -1.06%   3.15%   -6.35%  -10.30%   -9.45%
# Health Care             2.15%  -0.93%   2.19%   -6.51%  -11.10%  -11.17%
# Communication Services  1.28%   0.67%   2.77%   -8.54%  -16.59%  -14.94%
# Consumer Staples        1.23%  -1.20%   4.27%   -7.59%   -9.00%   -9.69%
#
#                              1Y       3Y       5Y      10Y
# ...
